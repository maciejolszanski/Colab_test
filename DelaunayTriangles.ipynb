# %% [markdown]
# <a href="https://colab.research.google.com/github/maciejolszanski/Colab_test/blob/main/DelaunayTriangles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import math
import scipy.spatial
import matplotlib.pyplot as plt

# ilosc punktów siatki
n = 600

szerokosc = 1
wysokosc = 1

# %%
rzedy = math.floor(math.sqrt(n))
print(rzedy)
# Out:
# 24

# %% [markdown]
# Siatka regularna

# %%
xi = np.arange(0, szerokosc + szerokosc/(rzedy), szerokosc/(rzedy-1))
yi = np.arange(0, wysokosc + wysokosc/(rzedy), wysokosc/(rzedy-1))
print(xi)
print(yi)
# Out:
# [0.         0.04347826 0.08695652 0.13043478 0.17391304 0.2173913
#  0.26086957 0.30434783 0.34782609 0.39130435 0.43478261 0.47826087
#  0.52173913 0.56521739 0.60869565 0.65217391 0.69565217 0.73913043
#  0.7826087  0.82608696 0.86956522 0.91304348 0.95652174 1.        ]
# [0.         0.04347826 0.08695652 0.13043478 0.17391304 0.2173913
#  0.26086957 0.30434783 0.34782609 0.39130435 0.43478261 0.47826087
#  0.52173913 0.56521739 0.60869565 0.65217391 0.69565217 0.73913043
#  0.7826087  0.82608696 0.86956522 0.91304348 0.95652174 1.        ]

# %%
points = np.zeros((n,2))
for wiersz in range(0, rzedy):
  for kolumna in range(0,rzedy):
    points[wiersz*(rzedy) + kolumna, 0] = xi[kolumna]
    points[wiersz*(rzedy) + kolumna, 1] = yi[wiersz]

# %%
tri = scipy.spatial.Delaunay(points)
plt.triplot(points[:,0], points[:,1], tri.simplices)
plt.show()
